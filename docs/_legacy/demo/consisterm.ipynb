# %%
# %run kineticEQ/tests/base/base_test.py --nx 100 --nv 20 --T_total 0.05 --tau_tilde 5e-6 --dt 5e-4 --lo_iter 2 --lo_tol 1e-2 --ho_iter 64 --ho_tol 1e-6 --Con_Terms_do

# %%
# %run kineticEQ/tests/base/base_test.py --nx 100 --nv 20 --T_total 0.05 --tau_tilde 5e-6 --dt 5e-4 --lo_iter 2 --lo_tol 1e-2 --ho_iter 64 --ho_tol 1e-6 --Con_Terms_do --flux_consistency_do

# %%
#%run kineticEQ/tests/base/base_test.py --nv 50 --T_total 0.05 --tau_tilde 5e-6 --dt 5e-4 --lo_iter 5 --lo_tol 1e-2 --ho_iter 64 --ho_tol 1e-6 --Con_Terms_do --flux_consistency_do --SVdown_do
