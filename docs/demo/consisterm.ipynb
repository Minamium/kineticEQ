# %%
# import packages
# %run kineticEQ/tests/base/base_test.py --T_total 0.005 --tau_tilde 5e-9 --dt 5e-4 --lo_iter 64 --lo_tol 1e-6 --ho_iter 64 --ho_tol 1e-6 --Con_Terms_do

# %%
# import packages
# %run kineticEQ/tests/base/base_test.py --T_total 0.005 --tau_tilde 5e-9 --dt 5e-4 --lo_iter 64 --lo_tol 1e-6 --ho_iter 64 --ho_tol 1e-6 --Con_Terms_do --flux_consistency_do

# %%
# import packages
# %run kineticEQ/tests/base/base_test.py --T_total 0.005 --tau_tilde 5e-9 --dt 5e-4 --lo_iter 64 --lo_tol 1e-6 --ho_iter 64 --ho_tol 1e-6 --Con_Terms_do --flux_consistency_do --SVdown_do
